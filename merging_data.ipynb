# %%
import pandas as pd
import os

# %%
walking_paths = [
    'archive/Walking-2023-09-16_18-14-40',
    'archive/Walking-2023-09-14_21-51-59'
]

sitting_paths = [
    'archive/Sitting-2023-10-18_09-05-37',
    'archive/Sitting-2023-09-14_09-11-15',
    'archive/Sitting-2023-09-14_08-37-45'
]

cycling_paths = [
    'archive/Cycling-2023-10-18_06-51-26',
    'archive/Cycling-2023-10-18_06-36-17',
    'archive/Cycling-2023-09-16_09-25-09',
    'archive/Cycling-2023-09-16_07-43-07',
    'archive/Cycling-2023-09-14_06-47-00',
    'archive/Cycling-2023-09-14_06-33-47',
    'archive/Cycling-2023-09-14_06-22-31'
]

# %%
def merge_data_by_filename(file_name, paths):
    frames = []
    for path in paths:
        data_frames = []
        for root, _, files in os.walk(path):
            for file in files:
                if file == file_name:
                    df = pd.read_csv(os.path.join(root, file))
                    activity = None
                    if 'Walking' in path:
                        activity = 'walking'
                    elif 'Sitting' in path:
                        activity = 'sitting'
                    elif 'Cycling' in path:
                        activity = 'cycling'
                    if activity is not None:
                        df['Activity'] = activity
                        data_frames.append(df)
        if data_frames:
            frames.append(pd.concat(data_frames))
    if frames:
        return pd.concat(frames)
    else:
        return None

# %%
paths_combined=walking_paths + sitting_paths + cycling_paths
orientation = merge_data_by_filename('Orientation.csv', paths_combined)
location=merge_data_by_filename('Location.csv', paths_combined)
total_acceleration=merge_data_by_filename('TotalAcceleration.csv', paths_combined)
magnetometer=merge_data_by_filename('Magnetometer.csv',paths_combined)
accelerometer=merge_data_by_filename('Accelerometer.csv',paths_combined)
location_gps=merge_data_by_filename('LocationGps.csv',paths_combined)
gyroscope=merge_data_by_filename('Gyroscope.csv',paths_combined)
pedometer=merge_data_by_filename('Pedometer.csv',paths_combined)
location_network=merge_data_by_filename('LocationNetwork.csv',paths_combined)
gravity=merge_data_by_filename('Gravity.csv',paths_combined)

# %%
data_frames = [orientation, location, total_acceleration, magnetometer, total_acceleration, 
               accelerometer, location_gps, gyroscope, pedometer, location_network, gravity]

parameter_names = ['Orientation', 'Location', 'Total Acceleration', 'Magnetometer', 'Total Acceleration', 
                   'Accelerometer', 'Location GPS', 'Gyroscope', 'Pedometer', 'Location Network', 'Gravity']

# %%
# Info about data and searching for missing values
for parameter, parameter_name in zip(data_frames, parameter_names):
    print("Info for parameter:", parameter_name)
    print(parameter.info())
    print("\nMissing values:")
    print(parameter.isnull().sum())
    print("\n")
# Out:
# Info for parameter: Orientation
# <class 'pandas.core.frame.DataFrame'>
# Index: 2775510 entries, 0 to 71460
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   time             int64
#  1   seconds_elapsed  float64
#  2   qz               float64
#  3   qy               float64
#  4   qx               float64
#  5   qw               float64
#  6   roll             float64
#  7   pitch            float64
#  8   yaw              float64
#  9   Activity         object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 232.9+ MB
# None
#
# Missing values:
# time               0
# seconds_elapsed    0
# qz                 0
# qy                 0
# qx                 0
# qw                 0
# roll               0
# pitch              2
# yaw                0
# Activity           0
# dtype: int64
#
#
# Info for parameter: Location
# <class 'pandas.core.frame.DataFrame'>
# Index: 8980 entries, 0 to 229
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                8980 non-null   int64
#  1   seconds_elapsed     8980 non-null   float64
#  2   bearingAccuracy     8980 non-null   float64
#  3   speedAccuracy       8980 non-null   float64
#  4   verticalAccuracy    8980 non-null   float64
#  5   horizontalAccuracy  8980 non-null   float64
#  6   speed               8980 non-null   float64
#  7   bearing             8980 non-null   float64
#  8   altitude            8980 non-null   float64
#  9   longitude           8980 non-null   float64
#  10  latitude            8980 non-null   float64
#  11  Activity            8980 non-null   object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 912.0+ KB
# None
#
# Missing values:
# time                  0
# seconds_elapsed       0
# bearingAccuracy       0
# speedAccuracy         0
# verticalAccuracy      0
# horizontalAccuracy    0
# speed                 0
# bearing               0
# altitude              0
# longitude             0
# latitude              0
# Activity              0
# dtype: int64
#
#
# Info for parameter: Total Acceleration
# <class 'pandas.core.frame.DataFrame'>
# Index: 2775495 entries, 0 to 71455
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   time             int64
#  1   seconds_elapsed  float64
#  2   z                float64
#  3   y                float64
#  4   x                float64
#  5   Activity         object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 148.2+ MB
# None
#
# Missing values:
# time               0
# seconds_elapsed    0
# z                  0
# y                  0
# x                  0
# Activity           0
# dtype: int64
#
#
# Info for parameter: Magnetometer
# <class 'pandas.core.frame.DataFrame'>
# Index: 364322 entries, 0 to 9036
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   time             364322 non-null  int64
#  1   seconds_elapsed  364322 non-null  float64
#  2   z                364322 non-null  float64
#  3   y                364322 non-null  float64
#  4   x                364322 non-null  float64
#  5   Activity         364322 non-null  object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 19.5+ MB
# None
#
# Missing values:
# time               0
# seconds_elapsed    0
# z                  0
# y                  0
# x                  0
# Activity           0
# dtype: int64
#
#
# Info for parameter: Total Acceleration
# <class 'pandas.core.frame.DataFrame'>
# Index: 2775495 entries, 0 to 71455
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   time             int64
#  1   seconds_elapsed  float64
#  2   z                float64
#  3   y                float64
#  4   x                float64
#  5   Activity         object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 148.2+ MB
# None
#
# Missing values:
# time               0
# seconds_elapsed    0
# z                  0
# y                  0
# x                  0
# Activity           0
# dtype: int64
#
#
# Info for parameter: Accelerometer
# <class 'pandas.core.frame.DataFrame'>
# Index: 2775511 entries, 0 to 71460
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   time             int64
#  1   seconds_elapsed  float64
#  2   z                float64
#  3   y                float64
#  4   x                float64
#  5   Activity         object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 148.2+ MB
# None
#
# Missing values:
# time               0
# seconds_elapsed    0
# z                  0
# y                  0
# x                  0
# Activity           0
# dtype: int64
#
#
# Info for parameter: Location GPS
# <class 'pandas.core.frame.DataFrame'>
# Index: 6552 entries, 0 to 180
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                6552 non-null   int64
#  1   seconds_elapsed     6552 non-null   float64
#  2   bearingAccuracy     6552 non-null   float64
#  3   speedAccuracy       6552 non-null   float64
#  4   verticalAccuracy    6552 non-null   float64
#  5   horizontalAccuracy  6552 non-null   float64
#  6   speed               6552 non-null   float64
#  7   bearing             6552 non-null   float64
#  8   altitude            6552 non-null   float64
#  9   longitude           6552 non-null   float64
#  10  latitude            6552 non-null   float64
#  11  Activity            6552 non-null   object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 665.4+ KB
# None
#
# Missing values:
# time                  0
# seconds_elapsed       0
# bearingAccuracy       0
# speedAccuracy         0
# verticalAccuracy      0
# horizontalAccuracy    0
# speed                 0
# bearing               0
# altitude              0
# longitude             0
# latitude              0
# Activity              0
# dtype: int64
#
#
# Info for parameter: Gyroscope
# <class 'pandas.core.frame.DataFrame'>
# Index: 2775857 entries, 0 to 71846
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   time             int64
#  1   seconds_elapsed  float64
#  2   z                float64
#  3   y                float64
#  4   x                float64
#  5   Activity         object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 148.2+ MB
# None
#
# Missing values:
# time               0
# seconds_elapsed    0
# z                  0
# y                  0
# x                  0
# Activity           0
# dtype: int64
#
#
# Info for parameter: Pedometer
# <class 'pandas.core.frame.DataFrame'>
# Index: 2073 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             2073 non-null   int64
#  1   seconds_elapsed  2073 non-null   float64
#  2   steps            2073 non-null   int64
#  3   Activity         2073 non-null   object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 81.0+ KB
# None
#
# Missing values:
# time               0
# seconds_elapsed    0
# steps              0
# Activity           0
# dtype: int64
#
#
# Info for parameter: Location Network
# <class 'pandas.core.frame.DataFrame'>
# Index: 647 entries, 0 to 16
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                647 non-null    int64
#  1   seconds_elapsed     647 non-null    float64
#  2   bearingAccuracy     647 non-null    int64
#  3   speedAccuracy       647 non-null    int64
#  4   verticalAccuracy    647 non-null    float64
#  5   horizontalAccuracy  647 non-null    float64
#  6   speed               647 non-null    int64
#  7   bearing             647 non-null    int64
#  8   altitude            647 non-null    float64
#  9   longitude           647 non-null    float64
#  10  latitude            647 non-null    float64
#  11  Activity            647 non-null    object
# dtypes: float64(6), int64(5), object(1)
# memory usage: 65.7+ KB
# None
#
# Missing values:
# time                  0
# seconds_elapsed       0
# bearingAccuracy       0
# speedAccuracy         0
# verticalAccuracy      0
# horizontalAccuracy    0
# speed                 0
# bearing               0
# altitude              0
# longitude             0
# latitude              0
# Activity              0
# dtype: int64
#
#
# Info for parameter: Gravity
# <class 'pandas.core.frame.DataFrame'>
# Index: 2775511 entries, 0 to 71460
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   time             int64
#  1   seconds_elapsed  float64
#  2   z                float64
#  3   y                float64
#  4   x                float64
#  5   Activity         object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 148.2+ MB
# None
#
# Missing values:
# time               0
# seconds_elapsed    0
# z                  0
# y                  0
# x                  0
# Activity           0
# dtype: int64

# %%
for parameter, parameter_name in zip(data_frames, parameter_names):
    print(parameter_name)
    print(parameter.head())
# Out:
# Orientation
#                   time  seconds_elapsed        qz        qy        qx  \
# 0  1694888080184831500         0.129832 -0.495947 -0.129112  0.153800
# 1  1694888080187351000         0.132351 -0.496316 -0.129446  0.153994
# 2  1694888080189870300         0.134870 -0.496670 -0.129838  0.154196
# 3  1694888080192389600         0.137390 -0.497005 -0.130284  0.154409
# 4  1694888080194909200         0.139909 -0.497314 -0.130776  0.154643
#
#          qw      roll     pitch       yaw Activity
# 0  0.844815 -0.071233 -0.398385  1.047297  walking
# 1  0.844512 -0.071450 -0.399103  1.048190  walking
# 2  0.844206 -0.071771 -0.399894  1.049035  walking
# 3  0.843902 -0.072187 -0.400758  1.049822  walking
# 4  0.843601 -0.072679 -0.401704  1.050542  walking
# Location
#                   time  seconds_elapsed  bearingAccuracy  speedAccuracy  \
# 0  1694888080756000000            0.701       179.899994            4.5
# 1  1694888081256000000            1.201       126.300003            8.4
# 2  1694888081358000000            1.303         0.000000            0.0
# 3  1694888081756000000            1.701        45.700001            6.8
# 4  1694888082320000000            2.265        26.299999            4.5
#
#    verticalAccuracy  horizontalAccuracy     speed    bearing  altitude  \
# 0        100.099998               8.200  1.129845  41.652626      81.4
# 1        100.099998              12.050  1.127248  41.896881      81.4
# 2          1.412915              13.428  1.120800  42.014912      92.0
# 3          1.416895              12.946  1.199251  42.999474      92.0
# 4          1.422535              12.217  1.357779  45.962059      92.0
#
#    longitude   latitude Activity
# 0   3.141929  50.683292  walking
# 1   3.141932  50.683292  walking
# 2   3.141931  50.683290  walking
# 3   3.141966  50.683304  walking
# 4   3.142031  50.683319  walking
# Total Acceleration
#                   time  seconds_elapsed          z        y        x Activity
# 0  1694888080182315000         0.127315   9.598950  4.39200  0.54000  walking
# 1  1694888080184831500         0.129832   9.834001  4.44705  0.58095  walking
# 2  1694888080187351000         0.132351  10.081051  4.40595  0.58305  walking
# 3  1694888080189870300         0.134870  10.198050  4.42800  0.69105  walking
# 4  1694888080192389600         0.137390  10.399051  4.53795  0.85395  walking
# Magnetometer
#                   time  seconds_elapsed          z        y          x  \
# 0  1694888080173253400         0.118253 -42.675003 -4.38750 -24.281252
# 1  1694888080193257700         0.138258 -43.106251 -4.57500 -24.806252
# 2  1694888080213271000         0.158271 -43.631252 -4.74375 -24.825001
# 3  1694888080233293600         0.178293 -43.312500 -5.79375 -24.243752
# 4  1694888080253321700         0.198322 -43.218750 -5.62500 -24.731251
#
#   Activity
# 0  walking
# 1  walking
# 2  walking
# 3  walking
# 4  walking
# Total Acceleration
#                   time  seconds_elapsed          z        y        x Activity
# 0  1694888080182315000         0.127315   9.598950  4.39200  0.54000  walking
# 1  1694888080184831500         0.129832   9.834001  4.44705  0.58095  walking
# 2  1694888080187351000         0.132351  10.081051  4.40595  0.58305  walking
# 3  1694888080189870300         0.134870  10.198050  4.42800  0.69105  walking
# 4  1694888080192389600         0.137390  10.399051  4.53795  0.85395  walking
# Accelerometer
#                   time  seconds_elapsed         z         y         x Activity
# 0  1694888080184831500         0.129832  0.818242  0.641601 -0.055491  walking
# 1  1694888080187351000         0.132351  1.068156  0.594020 -0.055157  walking
# 2  1694888080189870300         0.134870  1.188370  0.608928  0.050169  walking
# 3  1694888080192389600         0.137390  1.392931  0.711079  0.209552  walking
# 4  1694888080194909200         0.139909  1.470812  0.740644  0.253385  walking
# Location GPS
#                   time  seconds_elapsed  bearingAccuracy  speedAccuracy  \
# 0  1694888080756000000            0.701       179.899994            4.5
# 1  1694888081256000000            1.201       126.300003            8.4
# 2  1694888081756000000            1.701        45.700001            6.8
# 3  1694888082320000000            2.265        26.299999            4.5
# 4  1694888082820000000            2.765        19.200001            3.5
#
#    verticalAccuracy  horizontalAccuracy     speed     bearing  altitude  \
# 0        100.099998                 8.2  0.823041  260.720001      81.4
# 1        100.099998                15.9  2.801633   53.630001      81.4
# 2         66.000000                11.5  6.103576   48.230000      81.4
# 3         58.500000                 9.3  7.468105   62.290001      81.4
# 4         56.700001                 7.1  7.556122   59.250000      81.5
#
#    longitude   latitude Activity
# 0   3.141883  50.683260  walking
# 1   3.141920  50.683273  walking
# 2   3.142058  50.683335  walking
# 3   3.142150  50.683342  walking
# 4   3.142235  50.683390  walking
# Gyroscope
#                   time  seconds_elapsed         z         y         x Activity
# 0  1694888080152083000         0.097083 -0.186037 -0.161838  0.323537  walking
# 1  1694888080182315000         0.127315 -0.356263 -0.195800  0.235262  walking
# 2  1694888080184831500         0.129832 -0.346637 -0.225637  0.259737  walking
# 3  1694888080187351000         0.132351 -0.330687 -0.258637  0.289575  walking
# 4  1694888080189870300         0.134870 -0.312675 -0.286275  0.319275  walking
# Pedometer
#                   time  seconds_elapsed  steps Activity
# 0  1694888078392218600        -1.662781      0  walking
# 1  1694888080346059300         0.291059      2  walking
# 2  1694888082311337000         2.256337      5  walking
# 3  1694888084227868700         4.172869      7  walking
# 4  1694888086191603500         6.136604     11  walking
# Location Network
#                   time  seconds_elapsed  bearingAccuracy  speedAccuracy  \
# 0  1694888081358000000            1.303                0              0
# 1  1694888088829000000            8.774                0              0
# 2  1694888096034000000           15.979                0              0
# 3  1694888099241000000           19.186                0              0
# 4  1694888106163000000           26.108                0              0
#
#    verticalAccuracy  horizontalAccuracy  speed  bearing   altitude  longitude  \
# 0          1.412915           21.426001      0        0  92.000000   3.142203
# 1          1.265743           16.746000      0        0  91.800003   3.142424
# 2          1.275444           17.599001      0        0  91.800003   3.142415
# 3          1.449494           16.434999      0        0  91.500000   3.142538
# 4          1.347753           13.302000      0        0  91.400002   3.142628
#
#     latitude Activity
# 0  50.683345  walking
# 1  50.683464  walking
# 2  50.683431  walking
# 3  50.683565  walking
# 4  50.683572  walking
# Gravity
#                   time  seconds_elapsed         z         y         x Activity
# 0  1694888080184831500         0.129832  9.015759  3.805449  0.636441  walking
# 1  1694888080187351000         0.132351  9.012895  3.811930  0.638207  walking
# 2  1694888080189870300         0.134870  9.009681  3.819072  0.640881  walking
# 3  1694888080192389600         0.137390  9.006120  3.826871  0.644398  walking
# 4  1694888080194909200         0.139909  9.002189  3.835406  0.648565  walking
